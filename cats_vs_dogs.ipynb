# %% [markdown]
# Importing necessary packages

# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# Data Loading

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)

# %% [markdown]
# We can list the directories with the following terminal command:

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs

# %% [markdown]
# We'll now assign variables with the proper file path for the training and validation sets.

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

# %% [markdown]
# ### Understanding our data

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# ## Setting  Model Parameters

# %%
BATCH_SIZE = 100
IMG_SHAPE = 150

# %% [markdown]
# ### Data Preparation

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale = 1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory = validation_dir,
                                                              shuffle = False,
                                                              target_size = (IMG_SHAPE,IMG_SHAPE),
                                                              class_mode = 'binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_data_gen)

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])  # Plot images 0-4

# %% [markdown]
# # Model Creation

# %% [markdown]
# Define the model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu',input_shape = (150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128,(3,3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128,(3,3),activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation = 'relu'),
    tf.keras.layers.Dense(2)

])

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# <ipython-input-58-d70e0a339f06>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/100
# 20/20 [==============================] - 25s 497ms/step - loss: 0.7679 - accuracy: 0.5045 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 9s 441ms/step - loss: 0.6928 - accuracy: 0.5055 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 3/100
# 20/20 [==============================] - 12s 608ms/step - loss: 0.6878 - accuracy: 0.5575 - val_loss: 0.6875 - val_accuracy: 0.5040
# Epoch 4/100
# 20/20 [==============================] - 11s 536ms/step - loss: 0.6815 - accuracy: 0.5675 - val_loss: 0.6937 - val_accuracy: 0.5090
# Epoch 5/100
# 20/20 [==============================] - 11s 563ms/step - loss: 0.6909 - accuracy: 0.5240 - val_loss: 0.7081 - val_accuracy: 0.5000
# Epoch 6/100
# 20/20 [==============================] - 9s 464ms/step - loss: 0.6918 - accuracy: 0.5110 - val_loss: 0.6888 - val_accuracy: 0.5580
# Epoch 7/100
# 20/20 [==============================] - 9s 466ms/step - loss: 0.6740 - accuracy: 0.5695 - val_loss: 0.6799 - val_accuracy: 0.5460
# Epoch 8/100
# 20/20 [==============================] - 10s 490ms/step - loss: 0.6388 - accuracy: 0.6320 - val_loss: 0.7269 - val_accuracy: 0.5500
# Epoch 9/100
# 20/20 [==============================] - 10s 486ms/step - loss: 0.6204 - accuracy: 0.6585 - val_loss: 0.6813 - val_accuracy: 0.5780
# Epoch 10/100
# 20/20 [==============================] - 9s 473ms/step - loss: 0.5980 - accuracy: 0.6925 - val_loss: 0.6537 - val_accuracy: 0.6400
# Epoch 11/100
# 20/20 [==============================] - 10s 526ms/step - loss: 0.5871 - accuracy: 0.6850 - val_loss: 0.6354 - val_accuracy: 0.6640
# Epoch 12/100
# 20/20 [==============================] - 10s 476ms/step - loss: 0.5366 - accuracy: 0.7255 - val_loss: 0.6405 - val_accuracy: 0.6550
# Epoch 13/100
# 20/20 [==============================] - 10s 504ms/step - loss: 0.5122 - accuracy: 0.7515 - val_loss: 0.6426 - val_accuracy: 0.6650
# Epoch 14/100
# 20/20 [==============================] - 11s 538ms/step - loss: 0.4518 - accuracy: 0.7770 - val_loss: 0.6418 - val_accuracy: 0.6710
# Epoch 15/100
# 20/20 [==============================] - 11s 569ms/step - loss: 0.3918 - accuracy: 0.8285 - val_loss: 0.6584 - val_accuracy: 0.7080
# Epoch 16/100
# 20/20 [==============================] - 11s 569ms/step - loss: 0.3390 - accuracy: 0.8545 - val_loss: 0.7086 - val_accuracy: 0.7160
# Epoch 17/100
# 20/20 [==============================] - 9s 444ms/step - loss: 0.2996 - accuracy: 0.8685 - val_loss: 0.8529 - val_accuracy: 0.6830
# Epoch 18/100
# 20/20 [==============================] - 10s 486ms/step - loss: 0.2737 - accuracy: 0.8840 - val_loss: 0.7396 - val_accuracy: 0.6940
# Epoch 19/100
# 20/20 [==============================] - 10s 487ms/step - loss: 0.2109 - accuracy: 0.9175 - val_loss: 1.0211 - val_accuracy: 0.6860
# Epoch 20/100
# 20/20 [==============================] - 10s 491ms/step - loss: 0.1714 - accuracy: 0.9305 - val_loss: 0.9262 - val_accuracy: 0.7200
# Epoch 21/100
# 20/20 [==============================] - 10s 493ms/step - loss: 0.1179 - accuracy: 0.9555 - val_loss: 1.0705 - val_accuracy: 0.6990
# Epoch 22/100
# 20/20 [==============================] - 9s 450ms/step - loss: 0.0896 - accuracy: 0.9690 - val_loss: 1.1636 - val_accuracy: 0.7070
# Epoch 23/100
# 20/20 [==============================] - 10s 495ms/step - loss: 0.0644 - accuracy: 0.9780 - val_loss: 1.4113 - val_accuracy: 0.7090
# Epoch 24/100
# 20/20 [==============================] - 10s 492ms/step - loss: 0.0683 - accuracy: 0.9745 - val_loss: 1.4254 - val_accuracy: 0.7070
# Epoch 25/100
# 20/20 [==============================] - 10s 487ms/step - loss: 0.0612 - accuracy: 0.9770 - val_loss: 1.4224 - val_accuracy: 0.7010
# Epoch 26/100
# 20/20 [==============================] - 11s 570ms/step - loss: 0.0423 - accuracy: 0.9865 - val_loss: 1.7028 - val_accuracy: 0.7030
# Epoch 27/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 1.6286 - val_accuracy: 0.6920
# Epoch 28/100
# 20/20 [==============================] - 10s 502ms/step - loss: 0.0399 - accuracy: 0.9815 - val_loss: 1.7976 - val_accuracy: 0.6890
# Epoch 29/100
# 20/20 [==============================] - 10s 508ms/step - loss: 0.0957 - accuracy: 0.9605 - val_loss: 1.3008 - val_accuracy: 0.6750
# Epoch 30/100
# 20/20 [==============================] - 11s 536ms/step - loss: 0.0667 - accuracy: 0.9760 - val_loss: 1.6659 - val_accuracy: 0.7030
# Epoch 31/100
# 20/20 [==============================] - 11s 567ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 1.7137 - val_accuracy: 0.6980
# Epoch 32/100
# 20/20 [==============================] - 9s 465ms/step - loss: 0.0087 - accuracy: 0.9995 - val_loss: 1.8981 - val_accuracy: 0.7030
# Epoch 33/100
# 20/20 [==============================] - 10s 473ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0394 - val_accuracy: 0.7050
# Epoch 34/100
# 20/20 [==============================] - 10s 488ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.1129 - val_accuracy: 0.7130
# Epoch 35/100
# 20/20 [==============================] - 10s 490ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.2014 - val_accuracy: 0.7140
# Epoch 36/100
# 20/20 [==============================] - 11s 571ms/step - loss: 9.8268e-04 - accuracy: 1.0000 - val_loss: 2.2693 - val_accuracy: 0.7150
# Epoch 37/100
# 20/20 [==============================] - 9s 459ms/step - loss: 8.1815e-04 - accuracy: 1.0000 - val_loss: 2.3120 - val_accuracy: 0.7140
# Epoch 38/100
# 20/20 [==============================] - 10s 482ms/step - loss: 6.5863e-04 - accuracy: 1.0000 - val_loss: 2.3570 - val_accuracy: 0.7140
# Epoch 39/100
# 20/20 [==============================] - 10s 489ms/step - loss: 5.5178e-04 - accuracy: 1.0000 - val_loss: 2.3891 - val_accuracy: 0.7110
# Epoch 40/100
# 20/20 [==============================] - 10s 493ms/step - loss: 4.8384e-04 - accuracy: 1.0000 - val_loss: 2.4138 - val_accuracy: 0.7090
# Epoch 41/100
# 20/20 [==============================] - 11s 560ms/step - loss: 4.3032e-04 - accuracy: 1.0000 - val_loss: 2.4520 - val_accuracy: 0.7130
# Epoch 42/100
# 20/20 [==============================] - 9s 453ms/step - loss: 3.7004e-04 - accuracy: 1.0000 - val_loss: 2.4809 - val_accuracy: 0.7090
# Epoch 43/100
# 20/20 [==============================] - 10s 489ms/step - loss: 3.3398e-04 - accuracy: 1.0000 - val_loss: 2.5165 - val_accuracy: 0.7120
# Epoch 44/100
# 20/20 [==============================] - 10s 497ms/step - loss: 2.9451e-04 - accuracy: 1.0000 - val_loss: 2.5430 - val_accuracy: 0.7090
# Epoch 45/100
# 20/20 [==============================] - 10s 500ms/step - loss: 2.4883e-04 - accuracy: 1.0000 - val_loss: 2.5722 - val_accuracy: 0.7080
# Epoch 46/100
# 20/20 [==============================] - 9s 454ms/step - loss: 2.2713e-04 - accuracy: 1.0000 - val_loss: 2.5985 - val_accuracy: 0.7110
# Epoch 47/100
# 20/20 [==============================] - 11s 538ms/step - loss: 2.0140e-04 - accuracy: 1.0000 - val_loss: 2.6335 - val_accuracy: 0.7120
# Epoch 48/100
# 20/20 [==============================] - 10s 489ms/step - loss: 1.8353e-04 - accuracy: 1.0000 - val_loss: 2.6844 - val_accuracy: 0.7120
# Epoch 49/100
# 20/20 [==============================] - 10s 486ms/step - loss: 1.5949e-04 - accuracy: 1.0000 - val_loss: 2.6743 - val_accuracy: 0.7090
# Epoch 50/100
# 20/20 [==============================] - 9s 444ms/step - loss: 1.3916e-04 - accuracy: 1.0000 - val_loss: 2.6925 - val_accuracy: 0.7120
# Epoch 51/100
# 20/20 [==============================] - 10s 486ms/step - loss: 1.1990e-04 - accuracy: 1.0000 - val_loss: 2.7382 - val_accuracy: 0.7120
# Epoch 52/100
# 20/20 [==============================] - 10s 491ms/step - loss: 1.0858e-04 - accuracy: 1.0000 - val_loss: 2.7404 - val_accuracy: 0.7140
# Epoch 53/100
# 20/20 [==============================] - 10s 501ms/step - loss: 9.9263e-05 - accuracy: 1.0000 - val_loss: 2.7689 - val_accuracy: 0.7130
# Epoch 54/100
# 20/20 [==============================] - 9s 473ms/step - loss: 9.1746e-05 - accuracy: 1.0000 - val_loss: 2.7755 - val_accuracy: 0.7170
# Epoch 55/100
# 20/20 [==============================] - 9s 446ms/step - loss: 8.3212e-05 - accuracy: 1.0000 - val_loss: 2.7922 - val_accuracy: 0.7150
# Epoch 56/100
# 20/20 [==============================] - 10s 494ms/step - loss: 7.7033e-05 - accuracy: 1.0000 - val_loss: 2.8098 - val_accuracy: 0.7170
# Epoch 57/100
# 20/20 [==============================] - 10s 489ms/step - loss: 7.0070e-05 - accuracy: 1.0000 - val_loss: 2.8233 - val_accuracy: 0.7170
# Epoch 58/100
# 20/20 [==============================] - 10s 483ms/step - loss: 6.6732e-05 - accuracy: 1.0000 - val_loss: 2.8409 - val_accuracy: 0.7150
# Epoch 59/100
# 20/20 [==============================] - 9s 443ms/step - loss: 6.0974e-05 - accuracy: 1.0000 - val_loss: 2.8516 - val_accuracy: 0.7170
# Epoch 60/100
# 20/20 [==============================] - 10s 493ms/step - loss: 5.6558e-05 - accuracy: 1.0000 - val_loss: 2.8771 - val_accuracy: 0.7130
# Epoch 61/100
# 20/20 [==============================] - 10s 501ms/step - loss: 5.2292e-05 - accuracy: 1.0000 - val_loss: 2.8695 - val_accuracy: 0.7150
# Epoch 62/100
# 20/20 [==============================] - 10s 491ms/step - loss: 4.9289e-05 - accuracy: 1.0000 - val_loss: 2.8935 - val_accuracy: 0.7140
# Epoch 63/100
# 20/20 [==============================] - 11s 568ms/step - loss: 4.6940e-05 - accuracy: 1.0000 - val_loss: 2.8970 - val_accuracy: 0.7140
# Epoch 64/100
# 20/20 [==============================] - 9s 462ms/step - loss: 4.4289e-05 - accuracy: 1.0000 - val_loss: 2.9035 - val_accuracy: 0.7150
# Epoch 65/100
# 20/20 [==============================] - 10s 490ms/step - loss: 4.0738e-05 - accuracy: 1.0000 - val_loss: 2.9276 - val_accuracy: 0.7190
# Epoch 66/100
# 20/20 [==============================] - 10s 482ms/step - loss: 3.8242e-05 - accuracy: 1.0000 - val_loss: 2.9333 - val_accuracy: 0.7160
# Epoch 67/100
# 20/20 [==============================] - 11s 567ms/step - loss: 3.6354e-05 - accuracy: 1.0000 - val_loss: 2.9435 - val_accuracy: 0.7150
# Epoch 68/100
# 20/20 [==============================] - 9s 451ms/step - loss: 3.4316e-05 - accuracy: 1.0000 - val_loss: 2.9511 - val_accuracy: 0.7170
# Epoch 69/100
# 20/20 [==============================] - 10s 501ms/step - loss: 3.2542e-05 - accuracy: 1.0000 - val_loss: 2.9666 - val_accuracy: 0.7170
# Epoch 70/100
# 20/20 [==============================] - 10s 494ms/step - loss: 3.0610e-05 - accuracy: 1.0000 - val_loss: 2.9735 - val_accuracy: 0.7170
# Epoch 71/100
# 20/20 [==============================] - 10s 493ms/step - loss: 2.9004e-05 - accuracy: 1.0000 - val_loss: 2.9802 - val_accuracy: 0.7160
# Epoch 72/100
# 20/20 [==============================] - 9s 446ms/step - loss: 2.7705e-05 - accuracy: 1.0000 - val_loss: 2.9931 - val_accuracy: 0.7160
# Epoch 73/100
# 20/20 [==============================] - 10s 486ms/step - loss: 2.6769e-05 - accuracy: 1.0000 - val_loss: 3.0027 - val_accuracy: 0.7180
# Epoch 74/100
# 20/20 [==============================] - 10s 486ms/step - loss: 2.5265e-05 - accuracy: 1.0000 - val_loss: 3.0117 - val_accuracy: 0.7180
# Epoch 75/100
# 20/20 [==============================] - 10s 486ms/step - loss: 2.4242e-05 - accuracy: 1.0000 - val_loss: 3.0100 - val_accuracy: 0.7180
# Epoch 76/100
# 20/20 [==============================] - 11s 572ms/step - loss: 2.3181e-05 - accuracy: 1.0000 - val_loss: 3.0275 - val_accuracy: 0.7180
# Epoch 77/100
# 20/20 [==============================] - 9s 462ms/step - loss: 2.2166e-05 - accuracy: 1.0000 - val_loss: 3.0329 - val_accuracy: 0.7180
# Epoch 78/100
# 20/20 [==============================] - 9s 449ms/step - loss: 2.1750e-05 - accuracy: 1.0000 - val_loss: 3.0365 - val_accuracy: 0.7180
# Epoch 79/100
# 20/20 [==============================] - 10s 491ms/step - loss: 2.0702e-05 - accuracy: 1.0000 - val_loss: 3.0506 - val_accuracy: 0.7170
# Epoch 80/100
# 20/20 [==============================] - 11s 534ms/step - loss: 1.9555e-05 - accuracy: 1.0000 - val_loss: 3.0548 - val_accuracy: 0.7180
# Epoch 81/100
# 20/20 [==============================] - 10s 485ms/step - loss: 1.8887e-05 - accuracy: 1.0000 - val_loss: 3.0687 - val_accuracy: 0.7200
# Epoch 82/100
# 20/20 [==============================] - 9s 439ms/step - loss: 1.8283e-05 - accuracy: 1.0000 - val_loss: 3.0755 - val_accuracy: 0.7170
# Epoch 83/100
# 20/20 [==============================] - 10s 489ms/step - loss: 1.7215e-05 - accuracy: 1.0000 - val_loss: 3.0752 - val_accuracy: 0.7180
# Epoch 84/100
# 20/20 [==============================] - 10s 495ms/step - loss: 1.6508e-05 - accuracy: 1.0000 - val_loss: 3.0843 - val_accuracy: 0.7190
# Epoch 85/100
# 20/20 [==============================] - 10s 499ms/step - loss: 1.6194e-05 - accuracy: 1.0000 - val_loss: 3.0914 - val_accuracy: 0.7190
# Epoch 86/100
# 20/20 [==============================] - 11s 569ms/step - loss: 1.5516e-05 - accuracy: 1.0000 - val_loss: 3.0972 - val_accuracy: 0.7180
# Epoch 87/100
# 20/20 [==============================] - 11s 567ms/step - loss: 1.4880e-05 - accuracy: 1.0000 - val_loss: 3.1075 - val_accuracy: 0.7190
# Epoch 88/100
# 20/20 [==============================] - 9s 447ms/step - loss: 1.4392e-05 - accuracy: 1.0000 - val_loss: 3.1107 - val_accuracy: 0.7180
# Epoch 89/100
# 20/20 [==============================] - 10s 491ms/step - loss: 1.3793e-05 - accuracy: 1.0000 - val_loss: 3.1191 - val_accuracy: 0.7190
# Epoch 90/100
# 20/20 [==============================] - 10s 490ms/step - loss: 1.3438e-05 - accuracy: 1.0000 - val_loss: 3.1242 - val_accuracy: 0.7190
# Epoch 91/100
# 20/20 [==============================] - 10s 486ms/step - loss: 1.2911e-05 - accuracy: 1.0000 - val_loss: 3.1267 - val_accuracy: 0.7180
# Epoch 92/100
# 20/20 [==============================] - 11s 573ms/step - loss: 1.2507e-05 - accuracy: 1.0000 - val_loss: 3.1364 - val_accuracy: 0.7190
# Epoch 93/100
# 20/20 [==============================] - 9s 464ms/step - loss: 1.2031e-05 - accuracy: 1.0000 - val_loss: 3.1429 - val_accuracy: 0.7190
# Epoch 94/100
# 20/20 [==============================] - 10s 495ms/step - loss: 1.1685e-05 - accuracy: 1.0000 - val_loss: 3.1490 - val_accuracy: 0.7180
# Epoch 95/100
# 20/20 [==============================] - 10s 491ms/step - loss: 1.1368e-05 - accuracy: 1.0000 - val_loss: 3.1543 - val_accuracy: 0.7190
# Epoch 96/100
# 20/20 [==============================] - 11s 544ms/step - loss: 1.0884e-05 - accuracy: 1.0000 - val_loss: 3.1565 - val_accuracy: 0.7190
# Epoch 97/100
# 20/20 [==============================] - 9s 472ms/step - loss: 1.0572e-05 - accuracy: 1.0000 - val_loss: 3.1652 - val_accuracy: 0.7180
# Epoch 98/100
# 20/20 [==============================] - 10s 487ms/step - loss: 1.0323e-05 - accuracy: 1.0000 - val_loss: 3.1658 - val_accuracy: 0.7190
# Epoch 99/100
# 20/20 [==============================] - 10s 485ms/step - loss: 1.0025e-05 - accuracy: 1.0000 - val_loss: 3.1723 - val_accuracy: 0.7200
# Epoch 100/100
# 20/20 [==============================] - 11s 569ms/step - loss: 9.7059e-06 - accuracy: 1.0000 - val_loss: 3.1816 - val_accuracy: 0.7180

# %% [markdown]
# We'll now visualize the results we get after training our network.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()

# %% [markdown]
# As we can see from the plots, training accuracy and validation accuracy are off by large margin and our model has achieved only around 70% accuracy on the validation set (depending on the number of epochs you trained for).
#
# This is a clear indication of overfitting. Once the training and validation curves start to diverge, our model has started to memorize the training data and is unable to perform well on the validation data.
